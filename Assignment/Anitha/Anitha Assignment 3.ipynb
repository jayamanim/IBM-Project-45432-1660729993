# %% [markdown]
# # Example

# %% [markdown]
# Answer the questions or complete the tasks outlined in bold below , use the specific method described if applicable.

# %% [markdown]
# What is 7 to the power of 4 ? **bold text**

# %%
7**4
# Out:
# 2401

# %% [markdown]
# Split this String :**bold text**

# %% [markdown]
#
#           s = " Hi there Sam! "

# %% [markdown]
# into a list

# %%
s = "Hi there Sam!"

# %%
s.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %% [markdown]
# Given the variables :

# %% [markdown]
#         planet = "Earth"
#         diameter = 12742

# %% [markdown]
# Use .format() to print the following string:

# %% [markdown]
#       The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742
print("The diameter of {} is {} kilometers.".format(planet,diameter))
# Out:
# The diameter of Earth is 12742 kilometers.

# %% [markdown]
# Given this nested list, use indexing to grab the word "hello"

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %%
lst[3][1][2][0]
# Out:
# 'hello'

# %% [markdown]
# Given this nest dictionary grab the word "hello". Be prepared, this will be annoying/tricky

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# What is the main difference between a tuple and a list?

# %%
#Tuple is immutable where list is mutable

# %% [markdown]
# Create a function that grabs the email website domain from a string in the form:

# %% [markdown]
#           user@domain.com

# %% [markdown]
# So for example, passing "user@domain.com" would return: domain.com

# %%
def domainGet (email) :
    return email.split('@')[-1]

# %% [markdown]
# Create a basic function that returns True if the word 'dog' is contained in the input string. Don't worry about edge cases like a punctuation being attached to the word dog, but do account for capitalization.

# %%
def findDog(st):
    return 'dog' in st.lower().split()

# %%
findDog('Is there a dog here?')
# Out:
# True

# %% [markdown]
# Create a function that counts the number of times the word "dog" occurs in a string. Again ignore edge cases.

# %%
def countDog(st):
    count = 0
    for word in st.lower().split():
        if word == 'dog':
            count += 1
    return count

# %%
countDog('This dog runs faster than the other dog dude!')
# Out:
# 2

# %% [markdown]
# **Problem**

# %% [markdown]
# You are driving a little too fast, and a police officer stops you. Write a function to return one of 3 possible results: "No ticket", "Small ticket", or "Big Ticket". If your speed is 60 or less, the result is "No Ticket". If speed is between 61 and 80 inclusive, the result is "Small Ticket". If speed is 81 or more, the result is "Big Ticket". Unless it is your birthday (encoded as a boolean value in the parameters of the function) -- on your birthday, your speed can be 5 higher in all cases.

# %%
def caught_speeding(speed, is_birthday):
    
    if is_birthday:
        speeding = speed - 5
    else:
        speeding = speed
    
    if speeding > 80:
        return 'Big Ticket'
    elif speeding > 60:
        return 'Small Ticket'
    else:
        return 'No Ticket'

# %%
caught_speeding(81,False)
# Out:
# 'Big Ticket'

# %%
caught_speeding(70,True)
# Out:
# 'Small Ticket'

# %% [markdown]
# Create an employee list with basic salary values(at least 5 values for 5 employees) and using a for loop retreive each employee salary and calculate total salary expenditure.

# %%
employee = [30000,23000,25000,40000,33000]
tot = 0
for i in employee:
    tot = tot + i
print("Total Salary :",tot)
# Out:
# Total Salary : 151000

# %% [markdown]
# Create two dictionaries in Python:

# %% [markdown]
# First one to contain fields as Empid, Empname, Basicpay
#
# Second dictionary to contain fields as DeptName, DeptId.
#
# Combine both dictionaries.

# %%
dict1 = {
    "EmpId":[610219104003,610219104005,610219104010,610219104016],
    "EmpName":["ANITHA T","BAVISHA G","KALAIVANI S","MENAKA M"],
    "Basicpay":[42000,43000,44000,45000]
}

dict2 = {
    "DeptName":["CSE","CSE","CSE","CSE"],
    "DeptId":["CS03","CS05","CS10","CS16"]
}

dict1.update(dict2)
dict3 = dict1.copy()
dict3
# Out:
# {'EmpId': [610219104003, 610219104005, 610219104010, 610219104016],
#  'EmpName': ['ANITHA T', 'BAVISHA G', 'KALAIVANI S', 'MENAKA M'],
#  'Basicpay': [42000, 43000, 44000, 45000],
#  'DeptName': ['CSE', 'CSE', 'CSE', 'CSE'],
#  'DeptId': ['CS03', 'CS05', 'CS10', 'CS16']}
